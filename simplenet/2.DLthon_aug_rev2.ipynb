# %% [markdown]
# # Augmentation 2
# 두번째 try의 경우 첫번째 augmented 모델에서 적용한 augmentation 중 grayscale, resizecrop, gaussian blur을 제거하였다.
#
# 1.	Cifar10의 경우 피사체가 대부분 중간에 위치하여 자칫 이미지가 이동이 될 경우 일부분만 보고 판단을 하여 학습이 잘못 될 가능성이 높다고 판단됨
# 2.	32x32는 높은 화질의 사진이 아니기 때문에 blur을 추가하는 경우 사진 판독에 더 어려움이 있을 것으로 판단
# 됨
# 따라서 결론적으로 사진 촬영기종 또는 위치 등에 따라 변화될 수 있는 요소들만 남김

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
from torch.nn.modules.dropout import Dropout2d
# Simplenet 모델 정의
class SimpleNet(nn.Module):
    def __init__(self):
        super(SimpleNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),

            nn.Conv2d(64, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),

            nn.Conv2d(128, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,stride=2),
            nn.Dropout2d(0.1),

            nn.Conv2d(128, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),

            nn.Conv2d(128, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,stride=2),
            nn.Dropout2d(0.1),

            nn.Conv2d(256, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),

            nn.Conv2d(256, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,stride=2),
            nn.Dropout2d(0.1),

            nn.Conv2d(256, 512, 3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,stride=2),
            nn.Dropout2d(0.1),

            nn.Conv2d(512, 2048, 1),
            nn.BatchNorm2d(2048),
            nn.ReLU(inplace=True),

            nn.Conv2d(2048, 256, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,stride=2),
            nn.Dropout2d(0.1),

            nn.Conv2d(256, 256, 3,padding = 1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True)
            )
        self.classifier = nn.Linear(256, 10)



    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

# %%
# 클래스 레이블
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# 데이터 증강 설정
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# 테스트 데이터는 증강하지 않음
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# CIFAR-10 데이터셋 로드 (전체)
full_trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

# DataLoader를 사용하지 않고 데이터와 레이블 추출
full_train_data = list(full_trainset)
train_data, val_data = train_test_split(full_train_data, test_size=0.2, random_state=42)

# 훈련 데이터와 검증 데이터로 DataLoader 설정
trainloader = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True)
valloader = torch.utils.data.DataLoader(val_data, batch_size=64, shuffle=False)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False)


# 이미지를 보여주기 위한 함수
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis('off')

# 데이터 로더에서 하나의 배치를 불러오기 위해 for 루프 사용
for images, labels in trainloader:
    break  # 하나의 배치만 필요하므로 루프를 즉시 중단

# 이미지와 레이블을 3x3 그리드로 표시
fig = plt.figure(figsize=(9, 9))
for i in range(9):
    ax = fig.add_subplot(3, 3, i + 1)
    img = images[i] / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis('off')
    ax.set_title(classes[labels[i]])
plt.show()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# GPU 설정
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 모델, 손실 함수, 옵티마이저
model = SimpleNet().to("cuda")
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adadelta(model.parameters(), lr=0.1, rho=0.9, eps=0.001, weight_decay=0.002)

# 손실 및 정확도 리스트
train_loss_list = []
val_loss_list = []
train_acc_list = []
val_acc_list = []

# 훈련 루프
for epoch in range(150):
    model.train()
    running_loss = 0.0
    train_corrects = 0  # 추가된 코드

    for i, data in enumerate(trainloader, 0):
        inputs, labels = data
        inputs, labels = inputs.to("cuda"), labels.to("cuda")

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

        _, preds = torch.max(outputs, 1)
        train_corrects += torch.sum(preds == labels.data)

    # Validation
    model.eval()
    val_loss = 0.0
    val_corrects = 0

    with torch.no_grad():
        for i, data in enumerate(valloader, 0):
            inputs, labels = data
            inputs, labels = inputs.to("cuda"), labels.to("cuda")

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            _, preds = torch.max(outputs, 1)
            val_corrects += torch.sum(preds == labels.data)

    avg_train_loss = running_loss / len(trainloader)
    avg_val_loss = val_loss / len(valloader)
    val_acc = val_corrects.double().item() / len(valloader.dataset)
    train_acc = train_corrects.double().item() / len(trainloader.dataset)

    train_loss_list.append(avg_train_loss)
    val_loss_list.append(avg_val_loss)
    train_acc_list.append(train_acc)
    val_acc_list.append(val_acc)

    print(f"Epoch {epoch+1}, Training Loss: {avg_train_loss}, Train Acc: {train_acc:.4f}, Validation Loss: {avg_val_loss}, Validation Acc: {val_acc:.4f}")

# 손실 및 정확도 그래프 그리기
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.plot(val_loss_list, label='Validation Loss')
plt.legend()
plt.title('Loss')

plt.subplot(1, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.plot(val_acc_list, label='Validation Accuracy')
plt.legend()
plt.title('Accuracy')

plt.tight_layout()
plt.show()
# Out:
# Epoch 1, Training Loss: 1.512125865650177, Train Acc: 0.4457, Validation Loss: 1.2939445915495513, Validation Acc: 0.5378
# Epoch 2, Training Loss: 1.0632706212043763, Train Acc: 0.6233, Validation Loss: 0.9307359145705107, Validation Acc: 0.6696
# Epoch 3, Training Loss: 0.8761669848918915, Train Acc: 0.6945, Validation Loss: 0.7910928331362973, Validation Acc: 0.7253
# Epoch 4, Training Loss: 0.7706756309986115, Train Acc: 0.7327, Validation Loss: 0.8055565729262723, Validation Acc: 0.7258
# Epoch 5, Training Loss: 0.6886337658405304, Train Acc: 0.7621, Validation Loss: 0.7183730704769208, Validation Acc: 0.7524
# Epoch 6, Training Loss: 0.6230439713478089, Train Acc: 0.7853, Validation Loss: 0.6877560626928974, Validation Acc: 0.7630
# Epoch 7, Training Loss: 0.5712241126060486, Train Acc: 0.8007, Validation Loss: 0.7437129303528245, Validation Acc: 0.7506
# Epoch 8, Training Loss: 0.5217339967727661, Train Acc: 0.8177, Validation Loss: 0.7318491024576175, Validation Acc: 0.7528
# Epoch 9, Training Loss: 0.4744475908994675, Train Acc: 0.8384, Validation Loss: 0.6625548253773125, Validation Acc: 0.7759
# Epoch 10, Training Loss: 0.4447898330211639, Train Acc: 0.8494, Validation Loss: 0.6609254427206744, Validation Acc: 0.7764
# Epoch 11, Training Loss: 0.40539200921058655, Train Acc: 0.8618, Validation Loss: 0.6529310609504675, Validation Acc: 0.7821
# Epoch 12, Training Loss: 0.3737846030116081, Train Acc: 0.8729, Validation Loss: 0.7548167817531877, Validation Acc: 0.7564
# Epoch 13, Training Loss: 0.36344887433052064, Train Acc: 0.8780, Validation Loss: 0.7500139340093941, Validation Acc: 0.7552
# Epoch 14, Training Loss: 0.3364750300526619, Train Acc: 0.8861, Validation Loss: 0.7179334402843646, Validation Acc: 0.7637
# Epoch 15, Training Loss: 0.32971087965965273, Train Acc: 0.8894, Validation Loss: 0.6843987532482025, Validation Acc: 0.7802
# Epoch 16, Training Loss: 0.3190350691795349, Train Acc: 0.8912, Validation Loss: 0.7386214539503596, Validation Acc: 0.7597
# Epoch 17, Training Loss: 0.30258826274871825, Train Acc: 0.8993, Validation Loss: 0.7595985668480016, Validation Acc: 0.7531
# Epoch 18, Training Loss: 0.3030467481017113, Train Acc: 0.8970, Validation Loss: 0.6895947629099439, Validation Acc: 0.7801
# Epoch 19, Training Loss: 0.29436879144906997, Train Acc: 0.9026, Validation Loss: 0.6868694809971342, Validation Acc: 0.7800
# Epoch 20, Training Loss: 0.277713182079792, Train Acc: 0.9081, Validation Loss: 0.7159145529482774, Validation Acc: 0.7745
# Epoch 21, Training Loss: 0.2792133815765381, Train Acc: 0.9060, Validation Loss: 0.6936258259852222, Validation Acc: 0.7806
# Epoch 22, Training Loss: 0.2773861297011375, Train Acc: 0.9063, Validation Loss: 0.7166363031241545, Validation Acc: 0.7780
# Epoch 23, Training Loss: 0.2752142448782921, Train Acc: 0.9086, Validation Loss: 0.7320273710284263, Validation Acc: 0.7704
# Epoch 24, Training Loss: 0.2688625739812851, Train Acc: 0.9105, Validation Loss: 0.8136584238641581, Validation Acc: 0.7451
# Epoch 25, Training Loss: 0.25004958597421645, Train Acc: 0.9185, Validation Loss: 0.7765660191037852, Validation Acc: 0.7633
# Epoch 26, Training Loss: 0.2642962490320206, Train Acc: 0.9101, Validation Loss: 0.7852316567092944, Validation Acc: 0.7576
# Epoch 27, Training Loss: 0.2640736224412918, Train Acc: 0.9103, Validation Loss: 0.6791887398168539, Validation Acc: 0.7858
# Epoch 28, Training Loss: 0.25050549056529997, Train Acc: 0.9164, Validation Loss: 0.7694063439111042, Validation Acc: 0.7615
# Epoch 29, Training Loss: 0.2576138310134411, Train Acc: 0.9145, Validation Loss: 0.8075931210806415, Validation Acc: 0.7523
# Epoch 30, Training Loss: 0.24932949588298797, Train Acc: 0.9173, Validation Loss: 0.8061856424352926, Validation Acc: 0.7554
# Epoch 31, Training Loss: 0.2488050727248192, Train Acc: 0.9153, Validation Loss: 0.7895865248646706, Validation Acc: 0.7649
# Epoch 32, Training Loss: 0.24790164675712587, Train Acc: 0.9171, Validation Loss: 0.7580467082892254, Validation Acc: 0.7660
# Epoch 33, Training Loss: 0.24634177310466768, Train Acc: 0.9174, Validation Loss: 0.828465683255226, Validation Acc: 0.7483
# Epoch 34, Training Loss: 0.24977752994298935, Train Acc: 0.9160, Validation Loss: 0.7465160323935709, Validation Acc: 0.7783
# Epoch 35, Training Loss: 0.2331446920633316, Train Acc: 0.9225, Validation Loss: 0.6990979473302319, Validation Acc: 0.7847
# Epoch 36, Training Loss: 0.2360535878956318, Train Acc: 0.9229, Validation Loss: 0.7705494127455791, Validation Acc: 0.7668
# Epoch 37, Training Loss: 0.24810962020754815, Train Acc: 0.9179, Validation Loss: 0.6906528613369936, Validation Acc: 0.7841
# Epoch 38, Training Loss: 0.24207034500241278, Train Acc: 0.9190, Validation Loss: 0.7380024247868046, Validation Acc: 0.7726
# Epoch 39, Training Loss: 0.23951123037338257, Train Acc: 0.9211, Validation Loss: 0.7594356717197759, Validation Acc: 0.7684
# Epoch 40, Training Loss: 0.2335575963973999, Train Acc: 0.9230, Validation Loss: 0.826636662528773, Validation Acc: 0.7590
# Epoch 41, Training Loss: 0.2362725019931793, Train Acc: 0.9226, Validation Loss: 0.7092583752741479, Validation Acc: 0.7753
# Epoch 42, Training Loss: 0.22923514127135278, Train Acc: 0.9235, Validation Loss: 0.8163766839132187, Validation Acc: 0.7508
# Epoch 43, Training Loss: 0.23721486070156098, Train Acc: 0.9227, Validation Loss: 0.711480234838595, Validation Acc: 0.7807
# Epoch 44, Training Loss: 0.22425749396681785, Train Acc: 0.9256, Validation Loss: 0.7845061342617509, Validation Acc: 0.7638
# Epoch 45, Training Loss: 0.23756541877985002, Train Acc: 0.9197, Validation Loss: 0.8089694185241773, Validation Acc: 0.7564
# Epoch 46, Training Loss: 0.23702363950014113, Train Acc: 0.9192, Validation Loss: 0.6836097314479245, Validation Acc: 0.7934
# Epoch 47, Training Loss: 0.2318391757428646, Train Acc: 0.9234, Validation Loss: 0.7682226852626558, Validation Acc: 0.7684
# Epoch 48, Training Loss: 0.2357356585741043, Train Acc: 0.9212, Validation Loss: 0.7459233824614506, Validation Acc: 0.7702
# Epoch 49, Training Loss: 0.22631207525134087, Train Acc: 0.9246, Validation Loss: 0.6818620769461249, Validation Acc: 0.7887
# Epoch 50, Training Loss: 0.242864686191082, Train Acc: 0.9194, Validation Loss: 0.7497650610793168, Validation Acc: 0.7735
# Epoch 51, Training Loss: 0.22529673443436624, Train Acc: 0.9263, Validation Loss: 0.749288091803812, Validation Acc: 0.7725
# Epoch 52, Training Loss: 0.23082262212634086, Train Acc: 0.9241, Validation Loss: 0.8433402548929688, Validation Acc: 0.7488
# Epoch 53, Training Loss: 0.23228130714297296, Train Acc: 0.9240, Validation Loss: 0.7878914617808761, Validation Acc: 0.7651
# Epoch 54, Training Loss: 0.2262373759806156, Train Acc: 0.9244, Validation Loss: 0.759750938909069, Validation Acc: 0.7745
# Epoch 55, Training Loss: 0.22777838690876961, Train Acc: 0.9251, Validation Loss: 0.9320948334636202, Validation Acc: 0.7428
# Epoch 56, Training Loss: 0.22386493321061135, Train Acc: 0.9262, Validation Loss: 0.7658686271518659, Validation Acc: 0.7695
# Epoch 57, Training Loss: 0.2355337895989418, Train Acc: 0.9216, Validation Loss: 0.8019230181624175, Validation Acc: 0.7549
# Epoch 58, Training Loss: 0.2299279311478138, Train Acc: 0.9248, Validation Loss: 0.8326180863911938, Validation Acc: 0.7461
# Epoch 59, Training Loss: 0.22723961946964263, Train Acc: 0.9247, Validation Loss: 0.9150162599268993, Validation Acc: 0.7252
# Epoch 60, Training Loss: 0.22504108777046203, Train Acc: 0.9259, Validation Loss: 0.7274642022931652, Validation Acc: 0.7740
# Epoch 61, Training Loss: 0.21955523917078973, Train Acc: 0.9281, Validation Loss: 0.778670329387021, Validation Acc: 0.7678
# Epoch 62, Training Loss: 0.22746164705753327, Train Acc: 0.9245, Validation Loss: 0.7374023041527742, Validation Acc: 0.7790
# Epoch 63, Training Loss: 0.21663986327052118, Train Acc: 0.9286, Validation Loss: 0.7614913683408385, Validation Acc: 0.7699
# Epoch 64, Training Loss: 0.22014006773233413, Train Acc: 0.9289, Validation Loss: 0.8924254008159516, Validation Acc: 0.7422
# Epoch 65, Training Loss: 0.22420437299013138, Train Acc: 0.9266, Validation Loss: 0.8301578788620652, Validation Acc: 0.7551
# Epoch 66, Training Loss: 0.23163043372631073, Train Acc: 0.9242, Validation Loss: 0.7323221263422328, Validation Acc: 0.7775
# Epoch 67, Training Loss: 0.2178711925983429, Train Acc: 0.9284, Validation Loss: 0.7666746372250235, Validation Acc: 0.7723
# Epoch 68, Training Loss: 0.2260990425825119, Train Acc: 0.9251, Validation Loss: 0.8128148653325001, Validation Acc: 0.7601
# Epoch 69, Training Loss: 0.22561109288930892, Train Acc: 0.9257, Validation Loss: 1.0176448985269875, Validation Acc: 0.7199
# Epoch 70, Training Loss: 0.22029582370519638, Train Acc: 0.9260, Validation Loss: 0.8588441330346333, Validation Acc: 0.7475
# Epoch 71, Training Loss: 0.2214031120479107, Train Acc: 0.9276, Validation Loss: 0.7522419417739674, Validation Acc: 0.7751
# Epoch 72, Training Loss: 0.22693973973393441, Train Acc: 0.9254, Validation Loss: 0.7247670716161181, Validation Acc: 0.7800
# Epoch 73, Training Loss: 0.21367492449879646, Train Acc: 0.9303, Validation Loss: 0.9853547632124773, Validation Acc: 0.7198
# Epoch 74, Training Loss: 0.2296627093374729, Train Acc: 0.9242, Validation Loss: 0.7789891650722285, Validation Acc: 0.7657
# Epoch 75, Training Loss: 0.21851638172864915, Train Acc: 0.9284, Validation Loss: 0.7595046472017932, Validation Acc: 0.7730
# Epoch 76, Training Loss: 0.21815237429738044, Train Acc: 0.9290, Validation Loss: 0.739987715604199, Validation Acc: 0.7727
# Epoch 77, Training Loss: 0.22146298165321351, Train Acc: 0.9271, Validation Loss: 0.7395625746553871, Validation Acc: 0.7801
# Epoch 78, Training Loss: 0.22090421270132066, Train Acc: 0.9280, Validation Loss: 0.8553518210626712, Validation Acc: 0.7498
# Epoch 79, Training Loss: 0.2232141719818115, Train Acc: 0.9249, Validation Loss: 0.8262783740736117, Validation Acc: 0.7534
# Epoch 80, Training Loss: 0.2160942202746868, Train Acc: 0.9281, Validation Loss: 0.7510769856963188, Validation Acc: 0.7735
# Epoch 81, Training Loss: 0.21986107115745546, Train Acc: 0.9269, Validation Loss: 0.9495566677136026, Validation Acc: 0.7271
# Epoch 82, Training Loss: 0.22159128575921058, Train Acc: 0.9268, Validation Loss: 0.7816410713894352, Validation Acc: 0.7632
# Epoch 83, Training Loss: 0.213577155905962, Train Acc: 0.9299, Validation Loss: 1.0100686793114728, Validation Acc: 0.7214
# Epoch 84, Training Loss: 0.22000567969083787, Train Acc: 0.9287, Validation Loss: 1.0249727565771456, Validation Acc: 0.7217
# Epoch 85, Training Loss: 0.2231787058711052, Train Acc: 0.9270, Validation Loss: 0.7182005302161928, Validation Acc: 0.7871
# Epoch 86, Training Loss: 0.22136612469553948, Train Acc: 0.9271, Validation Loss: 0.8479802076983604, Validation Acc: 0.7477
# Epoch 87, Training Loss: 0.21484888672828675, Train Acc: 0.9310, Validation Loss: 0.8101617682511639, Validation Acc: 0.7623
# Epoch 88, Training Loss: 0.21856505287289618, Train Acc: 0.9278, Validation Loss: 0.6888958880096484, Validation Acc: 0.7914
# Epoch 89, Training Loss: 0.21739784047603608, Train Acc: 0.9284, Validation Loss: 0.7937838507306044, Validation Acc: 0.7630
# Epoch 90, Training Loss: 0.21785029443502427, Train Acc: 0.9294, Validation Loss: 0.7452707472880176, Validation Acc: 0.7681
# Epoch 91, Training Loss: 0.21784595866203307, Train Acc: 0.9286, Validation Loss: 0.7130952080723586, Validation Acc: 0.7842
# Epoch 92, Training Loss: 0.22359721189141274, Train Acc: 0.9267, Validation Loss: 0.7511106613714984, Validation Acc: 0.7712
# Epoch 93, Training Loss: 0.21334610196352005, Train Acc: 0.9291, Validation Loss: 0.8729873941202831, Validation Acc: 0.7470
# Epoch 94, Training Loss: 0.22101010743379593, Train Acc: 0.9261, Validation Loss: 0.9886939256054581, Validation Acc: 0.7284
# Epoch 95, Training Loss: 0.21124446608126163, Train Acc: 0.9306, Validation Loss: 0.7603327170678764, Validation Acc: 0.7741
# Epoch 96, Training Loss: 0.21668436004519462, Train Acc: 0.9291, Validation Loss: 0.9809051854595258, Validation Acc: 0.7224
# Epoch 97, Training Loss: 0.21953255589604379, Train Acc: 0.9281, Validation Loss: 0.7881751178176539, Validation Acc: 0.7665
# Epoch 98, Training Loss: 0.2132734562575817, Train Acc: 0.9310, Validation Loss: 0.7931241789820848, Validation Acc: 0.7647
# Epoch 99, Training Loss: 0.2200253351509571, Train Acc: 0.9282, Validation Loss: 0.7191267672238076, Validation Acc: 0.7777
# Epoch 100, Training Loss: 0.2157692367374897, Train Acc: 0.9290, Validation Loss: 0.9060325419447225, Validation Acc: 0.7354
# Epoch 101, Training Loss: 0.2188908034682274, Train Acc: 0.9284, Validation Loss: 0.8971588615399257, Validation Acc: 0.7378
# Epoch 102, Training Loss: 0.2167016857624054, Train Acc: 0.9294, Validation Loss: 0.8154080092527305, Validation Acc: 0.7627
# Epoch 103, Training Loss: 0.22046952432990075, Train Acc: 0.9263, Validation Loss: 0.881456262936258, Validation Acc: 0.7509
# Epoch 104, Training Loss: 0.21353151121139527, Train Acc: 0.9300, Validation Loss: 0.7264389801936545, Validation Acc: 0.7804
# Epoch 105, Training Loss: 0.22126008986234666, Train Acc: 0.9263, Validation Loss: 0.7748440902703887, Validation Acc: 0.7681
# Epoch 106, Training Loss: 0.21116058245897293, Train Acc: 0.9296, Validation Loss: 0.9583208703311386, Validation Acc: 0.7243
# Epoch 107, Training Loss: 0.2121177995622158, Train Acc: 0.9303, Validation Loss: 0.7022556199389658, Validation Acc: 0.7922
# Epoch 108, Training Loss: 0.21565037918686866, Train Acc: 0.9291, Validation Loss: 0.6947009901332247, Validation Acc: 0.7850
# Epoch 109, Training Loss: 0.2213422443151474, Train Acc: 0.9263, Validation Loss: 0.7898678637234269, Validation Acc: 0.7603
# Epoch 110, Training Loss: 0.20308249693512917, Train Acc: 0.9328, Validation Loss: 0.7469892936527349, Validation Acc: 0.7733
# Epoch 111, Training Loss: 0.21623866169452668, Train Acc: 0.9286, Validation Loss: 0.8845098831091717, Validation Acc: 0.7421
# Epoch 112, Training Loss: 0.2203158643603325, Train Acc: 0.9262, Validation Loss: 0.8181241154670715, Validation Acc: 0.7695
# Epoch 113, Training Loss: 0.21517342144846915, Train Acc: 0.9290, Validation Loss: 0.7127325863215574, Validation Acc: 0.7859
# Epoch 114, Training Loss: 0.2086265207707882, Train Acc: 0.9316, Validation Loss: 0.8372041273174012, Validation Acc: 0.7577
# Epoch 115, Training Loss: 0.21552786281704903, Train Acc: 0.9284, Validation Loss: 0.7634525509776583, Validation Acc: 0.7671
# Epoch 116, Training Loss: 0.2084447389781475, Train Acc: 0.9319, Validation Loss: 0.7808903463327201, Validation Acc: 0.7614
# Epoch 117, Training Loss: 0.2109009852349758, Train Acc: 0.9318, Validation Loss: 0.6864226881865483, Validation Acc: 0.7904
# Epoch 118, Training Loss: 0.2207985857963562, Train Acc: 0.9277, Validation Loss: 0.7754562601542018, Validation Acc: 0.7743
# Epoch 119, Training Loss: 0.21268360944390297, Train Acc: 0.9303, Validation Loss: 0.7213098518787675, Validation Acc: 0.7768
# Epoch 120, Training Loss: 0.21180216910243035, Train Acc: 0.9315, Validation Loss: 0.7920303426350758, Validation Acc: 0.7578
# Epoch 121, Training Loss: 0.2183714935362339, Train Acc: 0.9290, Validation Loss: 0.7405228098486639, Validation Acc: 0.7768
# Epoch 122, Training Loss: 0.21765149522423743, Train Acc: 0.9274, Validation Loss: 0.8356503244418247, Validation Acc: 0.7538
# Epoch 123, Training Loss: 0.21750803126692772, Train Acc: 0.9277, Validation Loss: 0.8960525701000432, Validation Acc: 0.7428
# Epoch 124, Training Loss: 0.21115238980054854, Train Acc: 0.9324, Validation Loss: 0.7393835490676248, Validation Acc: 0.7785
# Epoch 125, Training Loss: 0.21261818692684173, Train Acc: 0.9301, Validation Loss: 0.68622048056809, Validation Acc: 0.7892
# Epoch 126, Training Loss: 0.21361993524432182, Train Acc: 0.9302, Validation Loss: 0.7990441050878756, Validation Acc: 0.7625
# Epoch 127, Training Loss: 0.21256819068789481, Train Acc: 0.9300, Validation Loss: 0.742073911959958, Validation Acc: 0.7804
# Epoch 128, Training Loss: 0.22159948476552963, Train Acc: 0.9272, Validation Loss: 0.7076178232955325, Validation Acc: 0.7835
# Epoch 129, Training Loss: 0.21198784292340278, Train Acc: 0.9301, Validation Loss: 0.794678099643273, Validation Acc: 0.7666
# Epoch 130, Training Loss: 0.22054953839182853, Train Acc: 0.9275, Validation Loss: 0.7381566828413374, Validation Acc: 0.7765
# Epoch 131, Training Loss: 0.20554786578416825, Train Acc: 0.9324, Validation Loss: 0.8167637066476664, Validation Acc: 0.7557
# Epoch 132, Training Loss: 0.21610216922163963, Train Acc: 0.9297, Validation Loss: 0.7438696425431853, Validation Acc: 0.7763
# Epoch 133, Training Loss: 0.2151609511554241, Train Acc: 0.9299, Validation Loss: 0.713013629055327, Validation Acc: 0.7867
# Epoch 134, Training Loss: 0.21263338888287545, Train Acc: 0.9305, Validation Loss: 0.7771895098838077, Validation Acc: 0.7623
# Epoch 135, Training Loss: 0.21977041448950768, Train Acc: 0.9264, Validation Loss: 0.8836911899648654, Validation Acc: 0.7419
# Epoch 136, Training Loss: 0.21273370546102524, Train Acc: 0.9301, Validation Loss: 0.7326175135791682, Validation Acc: 0.7763
# Epoch 137, Training Loss: 0.21392626153230668, Train Acc: 0.9290, Validation Loss: 0.7327371754084423, Validation Acc: 0.7741
# Epoch 138, Training Loss: 0.20911295807361602, Train Acc: 0.9315, Validation Loss: 0.7608825837730602, Validation Acc: 0.7782
# Epoch 139, Training Loss: 0.22247493715882302, Train Acc: 0.9277, Validation Loss: 0.8911382183907138, Validation Acc: 0.7398
# Epoch 140, Training Loss: 0.21189399384260177, Train Acc: 0.9306, Validation Loss: 0.7331291038519258, Validation Acc: 0.7790
# Epoch 141, Training Loss: 0.2161377902507782, Train Acc: 0.9294, Validation Loss: 0.7957593801484746, Validation Acc: 0.7637
# Epoch 142, Training Loss: 0.20538123292922975, Train Acc: 0.9326, Validation Loss: 0.8186198531822034, Validation Acc: 0.7511
# Epoch 143, Training Loss: 0.21655050314068794, Train Acc: 0.9292, Validation Loss: 0.7806088709907167, Validation Acc: 0.7666
# Epoch 144, Training Loss: 0.21604265505671502, Train Acc: 0.9300, Validation Loss: 0.7712013964440413, Validation Acc: 0.7684
# Epoch 145, Training Loss: 0.20958092976212503, Train Acc: 0.9317, Validation Loss: 0.7504071676807039, Validation Acc: 0.7774
# Epoch 146, Training Loss: 0.212486554646492, Train Acc: 0.9302, Validation Loss: 0.7076633305876119, Validation Acc: 0.7866
# Epoch 147, Training Loss: 0.21378184323310853, Train Acc: 0.9312, Validation Loss: 0.7704108795922273, Validation Acc: 0.7740
# Epoch 148, Training Loss: 0.21332033618688584, Train Acc: 0.9298, Validation Loss: 0.7656109397578391, Validation Acc: 0.7730
# Epoch 149, Training Loss: 0.2123353037238121, Train Acc: 0.9298, Validation Loss: 0.7445357282450245, Validation Acc: 0.7813
# Epoch 150, Training Loss: 0.21123982048034667, Train Acc: 0.9315, Validation Loss: 0.8475643081270205, Validation Acc: 0.7516

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix


# 모델을 평가 모드로 설정
model.eval()

# 테스트 데이터셋에 대한 성능을 평가하기 위한 변수 초기화
test_loss = 0.0
test_corrects = 0

# Confusion matrix를 위한 레이블과 예측값을 저장할 리스트
true_labels = []
pred_labels = []

# GPU 설정 (이미 설정되어 있다면 생략 가능)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

with torch.no_grad():
    for inputs, labels in testloader:
        # 데이터를 GPU로 옮김 (이미 옮겨져 있다면 생략 가능)
        inputs, labels = inputs.to(device), labels.to(device)

        # 모델을 통해 예측 실행
        outputs = model(inputs)

        # 손실 계산
        loss = criterion(outputs, labels)

        # 테스트 손실 업데이트
        test_loss += loss.item() * inputs.size(0)

        # 예측값 계산
        _, preds = torch.max(outputs, 1)

        # 정확도 계산
        test_corrects += torch.sum(preds == labels.data)

        # 레이블과 예측값을 리스트에 추가
        true_labels.extend(labels.cpu().numpy())
        pred_labels.extend(preds.cpu().numpy())

# 평균 테스트 손실과 정확도 계산
test_loss = test_loss / len(testloader.dataset)
test_acc = test_corrects.double() / len(testloader.dataset)

print(f'Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}')

# Confusion matrix 계산
conf_matrix = confusion_matrix(true_labels, pred_labels)

# Confusion matrix를 그림으로 표시
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt="d",xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Test Loss: 0.7127, Test Acc: 0.7903
