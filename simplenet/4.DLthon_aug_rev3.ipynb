# %% [markdown]
# # Augmentation 3
# 데이터 셋의 크기가 작다고 판단되어 기존에 validation set으로 분리를 했던 데이터를 그냥 온전히 트레이닝 셋으로 넣음

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
from torch.nn.modules.dropout import Dropout2d
# Simplenet 모델 정의
class SimpleNet(nn.Module):
    def __init__(self):
        super(SimpleNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),

            nn.Conv2d(64, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),

            nn.Conv2d(128, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,stride=2),
            nn.Dropout2d(0.1),

            nn.Conv2d(128, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),

            nn.Conv2d(128, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,stride=2),
            nn.Dropout2d(0.1),

            nn.Conv2d(256, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),

            nn.Conv2d(256, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,stride=2),
            nn.Dropout2d(0.1),

            nn.Conv2d(256, 512, 3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,stride=2),
            nn.Dropout2d(0.1),

            nn.Conv2d(512, 2048, 1),
            nn.BatchNorm2d(2048),
            nn.ReLU(inplace=True),

            nn.Conv2d(2048, 256, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,stride=2),
            nn.Dropout2d(0.1),

            nn.Conv2d(256, 256, 3,padding = 1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True)
            )
        self.classifier = nn.Linear(256, 10)



    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

# %%
# 클래스 레이블
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# 데이터 증강 설정
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# 테스트 데이터는 증강하지 않음
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# CIFAR-10 데이터셋 로드 (전체)
full_trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)


# 훈련 데이터와 검증 데이터로 DataLoader 설정
trainloader = torch.utils.data.DataLoader(full_trainset, batch_size=64, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False)


# 이미지를 보여주기 위한 함수
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis('off')

# 데이터 로더에서 하나의 배치를 불러오기 위해 for 루프 사용
for images, labels in trainloader:
    break  # 하나의 배치만 필요하므로 루프를 즉시 중단

# 이미지와 레이블을 3x3 그리드로 표시
fig = plt.figure(figsize=(9, 9))
for i in range(9):
    ax = fig.add_subplot(3, 3, i + 1)
    img = images[i] / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis('off')
    ax.set_title(classes[labels[i]])
plt.show()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# GPU 설정
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 모델, 손실 함수, 옵티마이저
model = SimpleNet().to("cuda")
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adadelta(model.parameters(), lr=0.1, rho=0.9, eps=0.001, weight_decay=0.002)

# 손실 및 정확도 리스트
train_loss_list = []
train_acc_list = []

# 훈련 루프
for epoch in range(150):
    model.train()
    running_loss = 0.0
    train_corrects = 0  # 추가된 코드

    for i, data in enumerate(trainloader, 0):
        inputs, labels = data
        inputs, labels = inputs.to("cuda"), labels.to("cuda")

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

        _, preds = torch.max(outputs, 1)
        train_corrects += torch.sum(preds == labels.data)


    avg_train_loss = running_loss / len(trainloader)
    train_acc = train_corrects.double().item() / len(trainloader.dataset)

    train_loss_list.append(avg_train_loss)
    train_acc_list.append(train_acc)

    print(f"Epoch {epoch+1}, Training Loss: {avg_train_loss}, Train Acc: {train_acc:.4f}")

# 손실 및 정확도 그래프 그리기
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.legend()
plt.title('Loss')

plt.subplot(1, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.legend()
plt.title('Accuracy')

plt.tight_layout()
plt.show()
# Out:
# Epoch 1, Training Loss: 1.4377058271099539, Train Acc: 0.4791
# Epoch 2, Training Loss: 1.0037854233056382, Train Acc: 0.6486
# Epoch 3, Training Loss: 0.8459952980127481, Train Acc: 0.7063
# Epoch 4, Training Loss: 0.7663610582918767, Train Acc: 0.7345
# Epoch 5, Training Loss: 0.7055439564120739, Train Acc: 0.7581
# Epoch 6, Training Loss: 0.6665776141769136, Train Acc: 0.7734
# Epoch 7, Training Loss: 0.6340302416049611, Train Acc: 0.7844
# Epoch 8, Training Loss: 0.6025255126950076, Train Acc: 0.7968
# Epoch 9, Training Loss: 0.5803835927449223, Train Acc: 0.8008
# Epoch 10, Training Loss: 0.5635371516313394, Train Acc: 0.8079
# Epoch 11, Training Loss: 0.5480134280403252, Train Acc: 0.8148
# Epoch 12, Training Loss: 0.5376698767285213, Train Acc: 0.8191
# Epoch 13, Training Loss: 0.5307162736001831, Train Acc: 0.8217
# Epoch 14, Training Loss: 0.521591936878841, Train Acc: 0.8257
# Epoch 15, Training Loss: 0.5202276283670264, Train Acc: 0.8237
# Epoch 16, Training Loss: 0.5090756002823105, Train Acc: 0.8294
# Epoch 17, Training Loss: 0.504450123423658, Train Acc: 0.8302
# Epoch 18, Training Loss: 0.5025861674486218, Train Acc: 0.8290
# Epoch 19, Training Loss: 0.4957956415994088, Train Acc: 0.8330
# Epoch 20, Training Loss: 0.4909443052109245, Train Acc: 0.8359
# Epoch 21, Training Loss: 0.487137746018217, Train Acc: 0.8335
# Epoch 22, Training Loss: 0.48412348156618645, Train Acc: 0.8375
# Epoch 23, Training Loss: 0.4782894251444151, Train Acc: 0.8389
# Epoch 24, Training Loss: 0.47729139862691655, Train Acc: 0.8391
# Epoch 25, Training Loss: 0.47862137768350904, Train Acc: 0.8377
# Epoch 26, Training Loss: 0.4713525435008356, Train Acc: 0.8420
# Epoch 27, Training Loss: 0.4683328483377576, Train Acc: 0.8427
# Epoch 28, Training Loss: 0.4647178808822656, Train Acc: 0.8441
# Epoch 29, Training Loss: 0.4653651282343718, Train Acc: 0.8453
# Epoch 30, Training Loss: 0.4614166054884186, Train Acc: 0.8460
# Epoch 31, Training Loss: 0.46092590817328916, Train Acc: 0.8453
# Epoch 32, Training Loss: 0.46374183346319686, Train Acc: 0.8444
# Epoch 33, Training Loss: 0.45516439279555665, Train Acc: 0.8474
# Epoch 34, Training Loss: 0.4548327544766009, Train Acc: 0.8464
# Epoch 35, Training Loss: 0.46144512657771636, Train Acc: 0.8461
# Epoch 36, Training Loss: 0.4584897649105248, Train Acc: 0.8439
# Epoch 37, Training Loss: 0.4524579027767681, Train Acc: 0.8481
# Epoch 38, Training Loss: 0.45277684641158794, Train Acc: 0.8495
# Epoch 39, Training Loss: 0.44875991857036607, Train Acc: 0.8509
# Epoch 40, Training Loss: 0.44780461859825016, Train Acc: 0.8507
# Epoch 41, Training Loss: 0.44651353525002596, Train Acc: 0.8511
# Epoch 42, Training Loss: 0.4485996231779723, Train Acc: 0.8517
# Epoch 43, Training Loss: 0.45090000066534636, Train Acc: 0.8492
# Epoch 44, Training Loss: 0.4503210320535218, Train Acc: 0.8482
# Epoch 45, Training Loss: 0.44671010178373294, Train Acc: 0.8515
# Epoch 46, Training Loss: 0.44099164569316923, Train Acc: 0.8519
# Epoch 47, Training Loss: 0.44124536768859607, Train Acc: 0.8522
# Epoch 48, Training Loss: 0.44307667946876467, Train Acc: 0.8519
# Epoch 49, Training Loss: 0.437674261286588, Train Acc: 0.8530
# Epoch 50, Training Loss: 0.4372178218934847, Train Acc: 0.8536
# Epoch 51, Training Loss: 0.44113194283164675, Train Acc: 0.8531
# Epoch 52, Training Loss: 0.44169705557396344, Train Acc: 0.8526
# Epoch 53, Training Loss: 0.4403689353133711, Train Acc: 0.8534
# Epoch 54, Training Loss: 0.437386990298548, Train Acc: 0.8540
# Epoch 55, Training Loss: 0.4328029830856701, Train Acc: 0.8551
# Epoch 56, Training Loss: 0.4400936309295847, Train Acc: 0.8529
# Epoch 57, Training Loss: 0.4375318711066185, Train Acc: 0.8552
# Epoch 58, Training Loss: 0.4330231047728482, Train Acc: 0.8549
# Epoch 59, Training Loss: 0.4328897541479381, Train Acc: 0.8555
# Epoch 60, Training Loss: 0.4310795187835803, Train Acc: 0.8556
# Epoch 61, Training Loss: 0.4295031429575685, Train Acc: 0.8568
# Epoch 62, Training Loss: 0.43454285164165984, Train Acc: 0.8563
# Epoch 63, Training Loss: 0.4340546995096499, Train Acc: 0.8552
# Epoch 64, Training Loss: 0.433471090615253, Train Acc: 0.8549
# Epoch 65, Training Loss: 0.42849324940872924, Train Acc: 0.8566
# Epoch 66, Training Loss: 0.4281014960897548, Train Acc: 0.8581
# Epoch 67, Training Loss: 0.43286640355196754, Train Acc: 0.8557
# Epoch 68, Training Loss: 0.4274244028169786, Train Acc: 0.8582
# Epoch 69, Training Loss: 0.4283524548344295, Train Acc: 0.8566
# Epoch 70, Training Loss: 0.4289208829707807, Train Acc: 0.8580
# Epoch 71, Training Loss: 0.4359825097615152, Train Acc: 0.8567
# Epoch 72, Training Loss: 0.42836752221407487, Train Acc: 0.8567
# Epoch 73, Training Loss: 0.4282989374664434, Train Acc: 0.8579
# Epoch 74, Training Loss: 0.4312581159841374, Train Acc: 0.8565
# Epoch 75, Training Loss: 0.42547173664697907, Train Acc: 0.8579
# Epoch 76, Training Loss: 0.4296591666043567, Train Acc: 0.8563
# Epoch 77, Training Loss: 0.42650058135733276, Train Acc: 0.8568
# Epoch 78, Training Loss: 0.4274827945986977, Train Acc: 0.8570
# Epoch 79, Training Loss: 0.4239965544446655, Train Acc: 0.8594
# Epoch 80, Training Loss: 0.4254180090430448, Train Acc: 0.8582
# Epoch 81, Training Loss: 0.4229193461101378, Train Acc: 0.8578
# Epoch 82, Training Loss: 0.4280498914058556, Train Acc: 0.8580
# Epoch 83, Training Loss: 0.4247966919408735, Train Acc: 0.8588
# Epoch 84, Training Loss: 0.4246455663457856, Train Acc: 0.8588
# Epoch 85, Training Loss: 0.4225833548990357, Train Acc: 0.8596
# Epoch 86, Training Loss: 0.4237485269794379, Train Acc: 0.8597
# Epoch 87, Training Loss: 0.428604585892709, Train Acc: 0.8560
# Epoch 88, Training Loss: 0.41597365201129327, Train Acc: 0.8615
# Epoch 89, Training Loss: 0.4252504078514131, Train Acc: 0.8587
# Epoch 90, Training Loss: 0.42550606880803854, Train Acc: 0.8573
# Epoch 91, Training Loss: 0.4172785508605983, Train Acc: 0.8597
# Epoch 92, Training Loss: 0.4246825544959139, Train Acc: 0.8572
# Epoch 93, Training Loss: 0.4224095827402056, Train Acc: 0.8590
# Epoch 94, Training Loss: 0.4235119872233447, Train Acc: 0.8591
# Epoch 95, Training Loss: 0.41913594671375004, Train Acc: 0.8605
# Epoch 96, Training Loss: 0.41869208614920717, Train Acc: 0.8590
# Epoch 97, Training Loss: 0.42592990651841056, Train Acc: 0.8552
# Epoch 98, Training Loss: 0.4200920846951587, Train Acc: 0.8601
# Epoch 99, Training Loss: 0.4256158831060085, Train Acc: 0.8566
# Epoch 100, Training Loss: 0.41908387746423714, Train Acc: 0.8604
# Epoch 101, Training Loss: 0.4247405364575898, Train Acc: 0.8594
# Epoch 102, Training Loss: 0.4228575614178577, Train Acc: 0.8588
# Epoch 103, Training Loss: 0.4178811253603462, Train Acc: 0.8602
# Epoch 104, Training Loss: 0.41990812006585126, Train Acc: 0.8586
# Epoch 105, Training Loss: 0.4192019887935475, Train Acc: 0.8611
# Epoch 106, Training Loss: 0.42023734666426166, Train Acc: 0.8596
# Epoch 107, Training Loss: 0.4190108685008705, Train Acc: 0.8612
# Epoch 108, Training Loss: 0.421365988738549, Train Acc: 0.8593
# Epoch 109, Training Loss: 0.42440893569642013, Train Acc: 0.8578
# Epoch 110, Training Loss: 0.41844348380785157, Train Acc: 0.8603
# Epoch 111, Training Loss: 0.41184279981933897, Train Acc: 0.8629
# Epoch 112, Training Loss: 0.41661079793863587, Train Acc: 0.8596
# Epoch 113, Training Loss: 0.42045351134999026, Train Acc: 0.8592
# Epoch 114, Training Loss: 0.42169169393722966, Train Acc: 0.8592
# Epoch 115, Training Loss: 0.4216093388969636, Train Acc: 0.8595
# Epoch 116, Training Loss: 0.41315614306332205, Train Acc: 0.8617
# Epoch 117, Training Loss: 0.4242367413647644, Train Acc: 0.8587
# Epoch 118, Training Loss: 0.41227342142625845, Train Acc: 0.8627
# Epoch 119, Training Loss: 0.4180216492365693, Train Acc: 0.8606
# Epoch 120, Training Loss: 0.4208617429904011, Train Acc: 0.8600
# Epoch 121, Training Loss: 0.4169746994248132, Train Acc: 0.8609
# Epoch 122, Training Loss: 0.41407145742717605, Train Acc: 0.8629
# Epoch 123, Training Loss: 0.41308770679375706, Train Acc: 0.8624
# Epoch 124, Training Loss: 0.41740514789624594, Train Acc: 0.8617
# Epoch 125, Training Loss: 0.4161330256658747, Train Acc: 0.8621
# Epoch 126, Training Loss: 0.42178809507499876, Train Acc: 0.8614
# Epoch 127, Training Loss: 0.41842231244001243, Train Acc: 0.8595
# Epoch 128, Training Loss: 0.4160524469126216, Train Acc: 0.8619
# Epoch 129, Training Loss: 0.4163686333562407, Train Acc: 0.8613
# Epoch 130, Training Loss: 0.4138083659360171, Train Acc: 0.8621
# Epoch 131, Training Loss: 0.41533771081043935, Train Acc: 0.8598
# Epoch 132, Training Loss: 0.42001621686207974, Train Acc: 0.8588
# Epoch 133, Training Loss: 0.42013050701535876, Train Acc: 0.8600
# Epoch 134, Training Loss: 0.42101125929819044, Train Acc: 0.8613
# Epoch 135, Training Loss: 0.4143049585849733, Train Acc: 0.8611
# Epoch 136, Training Loss: 0.41581639737043236, Train Acc: 0.8622
# Epoch 137, Training Loss: 0.42260703156747476, Train Acc: 0.8595
# Epoch 138, Training Loss: 0.4178872502330319, Train Acc: 0.8604
# Epoch 139, Training Loss: 0.4183955862355964, Train Acc: 0.8598
# Epoch 140, Training Loss: 0.4159328630741905, Train Acc: 0.8610
# Epoch 141, Training Loss: 0.41364382243598513, Train Acc: 0.8630
# Epoch 142, Training Loss: 0.4127976381222305, Train Acc: 0.8637
# Epoch 143, Training Loss: 0.41931781426186454, Train Acc: 0.8598
# Epoch 144, Training Loss: 0.4150731841392834, Train Acc: 0.8611
# Epoch 145, Training Loss: 0.41879632337318967, Train Acc: 0.8618
# Epoch 146, Training Loss: 0.41624722675518, Train Acc: 0.8617
# Epoch 147, Training Loss: 0.4168556512278669, Train Acc: 0.8613
# Epoch 148, Training Loss: 0.41240613114879565, Train Acc: 0.8635
# Epoch 149, Training Loss: 0.41701866570107465, Train Acc: 0.8620
# Epoch 150, Training Loss: 0.41543128598681495, Train Acc: 0.8611

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix


# 모델을 평가 모드로 설정
model.eval()

# 테스트 데이터셋에 대한 성능을 평가하기 위한 변수 초기화
test_loss = 0.0
test_corrects = 0

# Confusion matrix를 위한 레이블과 예측값을 저장할 리스트
true_labels = []
pred_labels = []

# GPU 설정 (이미 설정되어 있다면 생략 가능)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

with torch.no_grad():
    for inputs, labels in testloader:
        # 데이터를 GPU로 옮김 (이미 옮겨져 있다면 생략 가능)
        inputs, labels = inputs.to(device), labels.to(device)

        # 모델을 통해 예측 실행
        outputs = model(inputs)

        # 손실 계산
        loss = criterion(outputs, labels)

        # 테스트 손실 업데이트
        test_loss += loss.item() * inputs.size(0)

        # 예측값 계산
        _, preds = torch.max(outputs, 1)

        # 정확도 계산
        test_corrects += torch.sum(preds == labels.data)

        # 레이블과 예측값을 리스트에 추가
        true_labels.extend(labels.cpu().numpy())
        pred_labels.extend(preds.cpu().numpy())

# 평균 테스트 손실과 정확도 계산
test_loss = test_loss / len(testloader.dataset)
test_acc = test_corrects.double() / len(testloader.dataset)

print(f'Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}')

# Confusion matrix 계산
conf_matrix = confusion_matrix(true_labels, pred_labels)

# Confusion matrix를 그림으로 표시
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt="d",xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Test Loss: 1.4214, Test Acc: 0.6063
