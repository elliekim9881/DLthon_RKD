# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import os
# %matplotlib inline

# %%
from torch.nn.modules.dropout import Dropout2d
# Simplenet 모델 정의
class SimpleNet(nn.Module):
    def __init__(self):
        super(SimpleNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),

            nn.Conv2d(64, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),

            nn.Conv2d(128, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,stride=2),
            nn.Dropout2d(0.1),

            nn.Conv2d(128, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),

            nn.Conv2d(128, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,stride=2),
            nn.Dropout2d(0.1),

            nn.Conv2d(256, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),

            nn.Conv2d(256, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,stride=2),
            nn.Dropout2d(0.1),

            nn.Conv2d(256, 512, 3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,stride=2),
            nn.Dropout2d(0.1),

            nn.Conv2d(512, 2048, 1),
            nn.BatchNorm2d(2048),
            nn.ReLU(inplace=True),

            nn.Conv2d(2048, 256, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,stride=2),
            nn.Dropout2d(0.1),

            nn.Conv2d(256, 256, 3,padding = 1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True)
            )
        self.classifier = nn.Linear(256, 10)



    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

# %%
# 클래스 레이블
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

transform_train = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# 테스트 데이터는 증강하지 않음
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# CIFAR-10 데이터셋 로드 (전체)
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

# 훈련 데이터와 검증 데이터로 DataLoader 설정
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False)


# 이미지를 보여주기 위한 함수
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis('off')

# 데이터 로더에서 하나의 배치를 불러오기 위해 for 루프 사용
for images, labels in trainloader:
    break  # 하나의 배치만 필요하므로 루프를 즉시 중단

# 이미지와 레이블을 3x3 그리드로 표시
fig = plt.figure(figsize=(9, 9))
for i in range(9):
    ax = fig.add_subplot(3, 3, i + 1)
    img = images[i] / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis('off')
    ax.set_title(classes[labels[i]])
plt.show()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# GPU 설정
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 모델, 손실 함수, 옵티마이저
model = SimpleNet().to("cuda")
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adadelta(model.parameters(), lr=0.1, rho=0.9, eps=0.001, weight_decay=0.002)

# 손실 및 정확도 리스트
train_loss_list = []
train_acc_list = []

# 훈련 루프
for epoch in range(150):
    model.train()
    running_loss = 0.0
    train_corrects = 0  # 추가된 코드

    for i, data in enumerate(trainloader, 0):
        inputs, labels = data
        inputs, labels = inputs.to("cuda"), labels.to("cuda")

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

        _, preds = torch.max(outputs, 1)
        train_corrects += torch.sum(preds == labels.data)


    avg_train_loss = running_loss / len(trainloader)
    train_acc = train_corrects.double().item() / len(trainloader.dataset)

    train_loss_list.append(avg_train_loss)
    train_acc_list.append(train_acc)

    print(f"Epoch {epoch+1}, Training Loss: {avg_train_loss}, Train Acc: {train_acc:.4f}")

# 손실 및 정확도 그래프 그리기
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.legend()
plt.title('Loss')

plt.subplot(1, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.legend()
plt.title('Accuracy')

plt.tight_layout()
plt.show()
# Out:
# Epoch 1, Training Loss: 1.2564312565662061, Train Acc: 0.5442
# Epoch 2, Training Loss: 0.8104999454506218, Train Acc: 0.7163
# Epoch 3, Training Loss: 0.657046916768374, Train Acc: 0.7764
# Epoch 4, Training Loss: 0.5639353819058069, Train Acc: 0.8083
# Epoch 5, Training Loss: 0.49855632788461185, Train Acc: 0.8314
# Epoch 6, Training Loss: 0.4494286072642907, Train Acc: 0.8474
# Epoch 7, Training Loss: 0.4005573026435759, Train Acc: 0.8668
# Epoch 8, Training Loss: 0.3746158923677471, Train Acc: 0.8744
# Epoch 9, Training Loss: 0.34271318530258926, Train Acc: 0.8850
# Epoch 10, Training Loss: 0.32073572171313686, Train Acc: 0.8935
# Epoch 11, Training Loss: 0.3048569291753842, Train Acc: 0.8970
# Epoch 12, Training Loss: 0.2897970836009363, Train Acc: 0.9028
# Epoch 13, Training Loss: 0.2756108108745969, Train Acc: 0.9091
# Epoch 14, Training Loss: 0.2666247633888441, Train Acc: 0.9115
# Epoch 15, Training Loss: 0.2636030094455118, Train Acc: 0.9133
# Epoch 16, Training Loss: 0.25667072929289486, Train Acc: 0.9161
# Epoch 17, Training Loss: 0.2508699699254978, Train Acc: 0.9166
# Epoch 18, Training Loss: 0.24666973075274465, Train Acc: 0.9177
# Epoch 19, Training Loss: 0.24361112225048073, Train Acc: 0.9183
# Epoch 20, Training Loss: 0.2396002249110995, Train Acc: 0.9200
# Epoch 21, Training Loss: 0.23107147406872428, Train Acc: 0.9239
# Epoch 22, Training Loss: 0.2382846614036261, Train Acc: 0.9209
# Epoch 23, Training Loss: 0.2258004871056513, Train Acc: 0.9252
# Epoch 24, Training Loss: 0.22362827051364248, Train Acc: 0.9261
# Epoch 25, Training Loss: 0.22673314142867426, Train Acc: 0.9252
# Epoch 26, Training Loss: 0.21961859134895265, Train Acc: 0.9273
# Epoch 27, Training Loss: 0.22274792253437553, Train Acc: 0.9253
# Epoch 28, Training Loss: 0.21740741564718355, Train Acc: 0.9284
# Epoch 29, Training Loss: 0.211921008575298, Train Acc: 0.9306
# Epoch 30, Training Loss: 0.21484210636571546, Train Acc: 0.9290
# Epoch 31, Training Loss: 0.21016961278970284, Train Acc: 0.9314
# Epoch 32, Training Loss: 0.21286946306924534, Train Acc: 0.9297
# Epoch 33, Training Loss: 0.21624957716278256, Train Acc: 0.9306
# Epoch 34, Training Loss: 0.2092834293313534, Train Acc: 0.9307
# Epoch 35, Training Loss: 0.2092207128520283, Train Acc: 0.9318
# Epoch 36, Training Loss: 0.20554231571228912, Train Acc: 0.9332
# Epoch 37, Training Loss: 0.20392364871871593, Train Acc: 0.9334
# Epoch 38, Training Loss: 0.2072850726735409, Train Acc: 0.9308
# Epoch 39, Training Loss: 0.20279545251213377, Train Acc: 0.9345
# Epoch 40, Training Loss: 0.2029590824442675, Train Acc: 0.9337
# Epoch 41, Training Loss: 0.20856647163658115, Train Acc: 0.9313
# Epoch 42, Training Loss: 0.20628356498658962, Train Acc: 0.9316
# Epoch 43, Training Loss: 0.20144036832882467, Train Acc: 0.9332
# Epoch 44, Training Loss: 0.20328981864749623, Train Acc: 0.9351
# Epoch 45, Training Loss: 0.20124455460387727, Train Acc: 0.9341
# Epoch 46, Training Loss: 0.19951475749406822, Train Acc: 0.9346
# Epoch 47, Training Loss: 0.2064422923890526, Train Acc: 0.9321
# Epoch 48, Training Loss: 0.1977120164800864, Train Acc: 0.9353
# Epoch 49, Training Loss: 0.20496856719446, Train Acc: 0.9325
# Epoch 50, Training Loss: 0.201132207399096, Train Acc: 0.9341
# Epoch 51, Training Loss: 0.19585641594055822, Train Acc: 0.9363
# Epoch 52, Training Loss: 0.2040631082718787, Train Acc: 0.9331
# Epoch 53, Training Loss: 0.19948597600602586, Train Acc: 0.9351
# Epoch 54, Training Loss: 0.20418486169413153, Train Acc: 0.9334
# Epoch 55, Training Loss: 0.19291905389474634, Train Acc: 0.9372
# Epoch 56, Training Loss: 0.19673382465625205, Train Acc: 0.9363
# Epoch 57, Training Loss: 0.19598916705573916, Train Acc: 0.9363
# Epoch 58, Training Loss: 0.19634883150296367, Train Acc: 0.9359
# Epoch 59, Training Loss: 0.19819589661877327, Train Acc: 0.9365
# Epoch 60, Training Loss: 0.19677403687840075, Train Acc: 0.9346
# Epoch 61, Training Loss: 0.1933490360808342, Train Acc: 0.9371
# Epoch 62, Training Loss: 0.1990718175907193, Train Acc: 0.9345
# Epoch 63, Training Loss: 0.19431516786327446, Train Acc: 0.9371
# Epoch 64, Training Loss: 0.1899620385654747, Train Acc: 0.9381
# Epoch 65, Training Loss: 0.2012187138133113, Train Acc: 0.9346
# Epoch 66, Training Loss: 0.19809723214086744, Train Acc: 0.9356
# Epoch 67, Training Loss: 0.19568384210567188, Train Acc: 0.9366
# Epoch 68, Training Loss: 0.19871860592509322, Train Acc: 0.9351
# Epoch 69, Training Loss: 0.20004834783980457, Train Acc: 0.9349
# Epoch 70, Training Loss: 0.19307140979315618, Train Acc: 0.9368
# Epoch 71, Training Loss: 0.19627323908650357, Train Acc: 0.9366
# Epoch 72, Training Loss: 0.19075155967508284, Train Acc: 0.9389
# Epoch 73, Training Loss: 0.19675267589233264, Train Acc: 0.9367
# Epoch 74, Training Loss: 0.19486285166819686, Train Acc: 0.9365
# Epoch 75, Training Loss: 0.19339564347834995, Train Acc: 0.9364
# Epoch 76, Training Loss: 0.19923768341636566, Train Acc: 0.9365
# Epoch 77, Training Loss: 0.1922696935170142, Train Acc: 0.9369
# Epoch 78, Training Loss: 0.19387180037091456, Train Acc: 0.9369
# Epoch 79, Training Loss: 0.19100756418255285, Train Acc: 0.9371
# Epoch 80, Training Loss: 0.1969771393862984, Train Acc: 0.9355
# Epoch 81, Training Loss: 0.19266752235572357, Train Acc: 0.9377
# Epoch 82, Training Loss: 0.19562660805318896, Train Acc: 0.9357
# Epoch 83, Training Loss: 0.18674937703782488, Train Acc: 0.9393
# Epoch 84, Training Loss: 0.19099562155926014, Train Acc: 0.9379
# Epoch 85, Training Loss: 0.1924243327944785, Train Acc: 0.9383
# Epoch 86, Training Loss: 0.19045739457763902, Train Acc: 0.9384
# Epoch 87, Training Loss: 0.19409342329768117, Train Acc: 0.9359
# Epoch 88, Training Loss: 0.18720328845226628, Train Acc: 0.9392
# Epoch 89, Training Loss: 0.19380455793303145, Train Acc: 0.9369
# Epoch 90, Training Loss: 0.19594099647734706, Train Acc: 0.9352
# Epoch 91, Training Loss: 0.19276101212910451, Train Acc: 0.9364
# Epoch 92, Training Loss: 0.19115982084627955, Train Acc: 0.9375
# Epoch 93, Training Loss: 0.19307543968548402, Train Acc: 0.9374
# Epoch 94, Training Loss: 0.19122400905822626, Train Acc: 0.9375
# Epoch 95, Training Loss: 0.18735769482048423, Train Acc: 0.9391
# Epoch 96, Training Loss: 0.19552935382155964, Train Acc: 0.9367
# Epoch 97, Training Loss: 0.1900684107142641, Train Acc: 0.9384
# Epoch 98, Training Loss: 0.18882752830148353, Train Acc: 0.9383
# Epoch 99, Training Loss: 0.19486485180371177, Train Acc: 0.9359
# Epoch 100, Training Loss: 0.1909577029392771, Train Acc: 0.9381
# Epoch 101, Training Loss: 0.19036234897154067, Train Acc: 0.9384
# Epoch 102, Training Loss: 0.19172753080192123, Train Acc: 0.9375
# Epoch 103, Training Loss: 0.1902298772721873, Train Acc: 0.9382
# Epoch 104, Training Loss: 0.19177115431336492, Train Acc: 0.9379
# Epoch 105, Training Loss: 0.1876497142293188, Train Acc: 0.9393
# Epoch 106, Training Loss: 0.19488635714477895, Train Acc: 0.9368
# Epoch 107, Training Loss: 0.1898972802793088, Train Acc: 0.9396
# Epoch 108, Training Loss: 0.18941656759728098, Train Acc: 0.9382
# Epoch 109, Training Loss: 0.1860797906418324, Train Acc: 0.9399
# Epoch 110, Training Loss: 0.19124903004435476, Train Acc: 0.9365
# Epoch 111, Training Loss: 0.19163149017888262, Train Acc: 0.9386
# Epoch 112, Training Loss: 0.1911931590551077, Train Acc: 0.9381
# Epoch 113, Training Loss: 0.19210963645268736, Train Acc: 0.9387
# Epoch 114, Training Loss: 0.19397364626102664, Train Acc: 0.9367
# Epoch 115, Training Loss: 0.19157306989059425, Train Acc: 0.9389
# Epoch 116, Training Loss: 0.19041340383689118, Train Acc: 0.9390
# Epoch 117, Training Loss: 0.1903750076508888, Train Acc: 0.9376
# Epoch 118, Training Loss: 0.18681705039461402, Train Acc: 0.9397
# Epoch 119, Training Loss: 0.18729273039761865, Train Acc: 0.9396
# Epoch 120, Training Loss: 0.19095234993054433, Train Acc: 0.9374
# Epoch 121, Training Loss: 0.18837729191212246, Train Acc: 0.9394
# Epoch 122, Training Loss: 0.18301201577457932, Train Acc: 0.9403
# Epoch 123, Training Loss: 0.19366371197402096, Train Acc: 0.9375
# Epoch 124, Training Loss: 0.18385258020923648, Train Acc: 0.9399
# Epoch 125, Training Loss: 0.19419346213378869, Train Acc: 0.9356
# Epoch 126, Training Loss: 0.19537204967054259, Train Acc: 0.9363
# Epoch 127, Training Loss: 0.19334386053788083, Train Acc: 0.9372
# Epoch 128, Training Loss: 0.188683972286675, Train Acc: 0.9384
# Epoch 129, Training Loss: 0.19141333867007357, Train Acc: 0.9376
# Epoch 130, Training Loss: 0.18836702630781305, Train Acc: 0.9387
# Epoch 131, Training Loss: 0.1817335518567687, Train Acc: 0.9417
# Epoch 132, Training Loss: 0.1871012410010828, Train Acc: 0.9396
# Epoch 133, Training Loss: 0.18854336936950988, Train Acc: 0.9386
# Epoch 134, Training Loss: 0.19521870244475428, Train Acc: 0.9367
# Epoch 135, Training Loss: 0.1893319788929599, Train Acc: 0.9392
# Epoch 136, Training Loss: 0.18620721372963903, Train Acc: 0.9405
# Epoch 137, Training Loss: 0.19208288904222304, Train Acc: 0.9390
# Epoch 138, Training Loss: 0.1859802393733388, Train Acc: 0.9405
# Epoch 139, Training Loss: 0.18655999983325028, Train Acc: 0.9398
# Epoch 140, Training Loss: 0.18904147859272138, Train Acc: 0.9393
# Epoch 141, Training Loss: 0.18579598520275042, Train Acc: 0.9388
# Epoch 142, Training Loss: 0.1897530554677062, Train Acc: 0.9389
# Epoch 143, Training Loss: 0.18739128410768555, Train Acc: 0.9389
# Epoch 144, Training Loss: 0.19372137198629585, Train Acc: 0.9374
# Epoch 145, Training Loss: 0.19018608059429223, Train Acc: 0.9391
# Epoch 146, Training Loss: 0.1890980392894553, Train Acc: 0.9394
# Epoch 147, Training Loss: 0.18714201762138502, Train Acc: 0.9383
# Epoch 148, Training Loss: 0.19021355527002945, Train Acc: 0.9386
# Epoch 149, Training Loss: 0.18775740219399217, Train Acc: 0.9397
# Epoch 150, Training Loss: 0.18993125744926198, Train Acc: 0.9381

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix


# 모델을 평가 모드로 설정
model.eval()

# 테스트 데이터셋에 대한 성능을 평가하기 위한 변수 초기화
test_loss = 0.0
test_corrects = 0

# Confusion matrix를 위한 레이블과 예측값을 저장할 리스트
true_labels = []
pred_labels = []

# GPU 설정 (이미 설정되어 있다면 생략 가능)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

with torch.no_grad():
    for inputs, labels in testloader:
        # 데이터를 GPU로 옮김 (이미 옮겨져 있다면 생략 가능)
        inputs, labels = inputs.to(device), labels.to(device)

        # 모델을 통해 예측 실행
        outputs = model(inputs)

        # 손실 계산
        loss = criterion(outputs, labels)

        # 테스트 손실 업데이트
        test_loss += loss.item() * inputs.size(0)

        # 예측값 계산
        _, preds = torch.max(outputs, 1)

        # 정확도 계산
        test_corrects += torch.sum(preds == labels.data)

        # 레이블과 예측값을 리스트에 추가
        true_labels.extend(labels.cpu().numpy())
        pred_labels.extend(preds.cpu().numpy())

# 평균 테스트 손실과 정확도 계산
test_loss = test_loss / len(testloader.dataset)
test_acc = test_corrects.double() / len(testloader.dataset)

print(f'Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}')

# Confusion matrix 계산
conf_matrix = confusion_matrix(true_labels, pred_labels)

# Confusion matrix를 그림으로 표시
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt="d",xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Test Loss: 0.6397, Test Acc: 0.8046
