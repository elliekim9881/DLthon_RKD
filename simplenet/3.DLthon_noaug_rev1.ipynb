# %% [markdown]
# Augmentation 1,2에 대응하는 augmentation을 적용하지 않은 모델

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import os
# %matplotlib inline

# %%
from torch.nn.modules.dropout import Dropout2d
# Simplenet 모델 정의
class SimpleNet(nn.Module):
    def __init__(self):
        super(SimpleNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),

            nn.Conv2d(64, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),

            nn.Conv2d(128, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,stride=2),
            nn.Dropout2d(0.1),

            nn.Conv2d(128, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),

            nn.Conv2d(128, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,stride=2),
            nn.Dropout2d(0.1),

            nn.Conv2d(256, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),

            nn.Conv2d(256, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,stride=2),
            nn.Dropout2d(0.1),

            nn.Conv2d(256, 512, 3, padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,stride=2),
            nn.Dropout2d(0.1),

            nn.Conv2d(512, 2048, 1),
            nn.BatchNorm2d(2048),
            nn.ReLU(inplace=True),

            nn.Conv2d(2048, 256, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2,stride=2),
            nn.Dropout2d(0.1),

            nn.Conv2d(256, 256, 3,padding = 1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True)
            )
        self.classifier = nn.Linear(256, 10)



    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

# %%
# 클래스 레이블
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

transform_train = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# 테스트 데이터는 증강하지 않음
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# CIFAR-10 데이터셋 로드 (전체)
full_trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

# DataLoader를 사용하지 않고 데이터와 레이블 추출
full_train_data = list(full_trainset)
train_data, val_data = train_test_split(full_train_data, test_size=0.2, random_state=42)

# 훈련 데이터와 검증 데이터로 DataLoader 설정
trainloader = torch.utils.data.DataLoader(train_data, batch_size=64, shuffle=True)
valloader = torch.utils.data.DataLoader(val_data, batch_size=64, shuffle=False)
testloader = torch.utils.data.DataLoader(testset, batch_size=64, shuffle=False)


# 이미지를 보여주기 위한 함수
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis('off')

# 데이터 로더에서 하나의 배치를 불러오기 위해 for 루프 사용
for images, labels in trainloader:
    break  # 하나의 배치만 필요하므로 루프를 즉시 중단

# 이미지와 레이블을 3x3 그리드로 표시
fig = plt.figure(figsize=(9, 9))
for i in range(9):
    ax = fig.add_subplot(3, 3, i + 1)
    img = images[i] / 2 + 0.5  # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.axis('off')
    ax.set_title(classes[labels[i]])
plt.show()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# GPU 설정
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 모델, 손실 함수, 옵티마이저
model = SimpleNet().to("cuda")
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adadelta(model.parameters(), lr=0.1, rho=0.9, eps=0.001, weight_decay=0.002)

# 손실 및 정확도 리스트
train_loss_list = []
val_loss_list = []
train_acc_list = []
val_acc_list = []

# 훈련 루프
for epoch in range(150):
    model.train()
    running_loss = 0.0
    train_corrects = 0  # 추가된 코드

    for i, data in enumerate(trainloader, 0):
        inputs, labels = data
        inputs, labels = inputs.to("cuda"), labels.to("cuda")

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

        _, preds = torch.max(outputs, 1)
        train_corrects += torch.sum(preds == labels.data)

    # Validation
    model.eval()
    val_loss = 0.0
    val_corrects = 0

    with torch.no_grad():
        for i, data in enumerate(valloader, 0):
            inputs, labels = data
            inputs, labels = inputs.to("cuda"), labels.to("cuda")

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            _, preds = torch.max(outputs, 1)
            val_corrects += torch.sum(preds == labels.data)

    avg_train_loss = running_loss / len(trainloader)
    avg_val_loss = val_loss / len(valloader)
    val_acc = val_corrects.double().item() / len(valloader.dataset)
    train_acc = train_corrects.double().item() / len(trainloader.dataset)

    train_loss_list.append(avg_train_loss)
    val_loss_list.append(avg_val_loss)
    train_acc_list.append(train_acc)
    val_acc_list.append(val_acc)

    print(f"Epoch {epoch+1}, Training Loss: {avg_train_loss}, Train Acc: {train_acc:.4f}, Validation Loss: {avg_val_loss}, Validation Acc: {val_acc:.4f}")

# 손실 및 정확도 그래프 그리기
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.plot(val_loss_list, label='Validation Loss')
plt.legend()
plt.title('Loss')

plt.subplot(1, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.plot(val_acc_list, label='Validation Accuracy')
plt.legend()
plt.title('Accuracy')

plt.tight_layout()
plt.show()
# Out:
# Epoch 1, Training Loss: 1.351927430343628, Train Acc: 0.5100, Validation Loss: 1.062902410318897, Validation Acc: 0.6155
# Epoch 2, Training Loss: 0.8884389678001404, Train Acc: 0.6895, Validation Loss: 0.7732645599705399, Validation Acc: 0.7341
# Epoch 3, Training Loss: 0.7165203760147095, Train Acc: 0.7517, Validation Loss: 0.6533505804599471, Validation Acc: 0.7746
# Epoch 4, Training Loss: 0.6091479511737824, Train Acc: 0.7909, Validation Loss: 0.5909979396564945, Validation Acc: 0.8029
# Epoch 5, Training Loss: 0.532585485124588, Train Acc: 0.8184, Validation Loss: 0.5920075734329832, Validation Acc: 0.7966
# Epoch 6, Training Loss: 0.4815782868146896, Train Acc: 0.8372, Validation Loss: 0.555334784043063, Validation Acc: 0.8110
# Epoch 7, Training Loss: 0.4358213307619095, Train Acc: 0.8521, Validation Loss: 0.5115080226189012, Validation Acc: 0.8269
# Epoch 8, Training Loss: 0.39245011627674103, Train Acc: 0.8679, Validation Loss: 0.5279402930265779, Validation Acc: 0.8266
# Epoch 9, Training Loss: 0.3519035016536713, Train Acc: 0.8823, Validation Loss: 0.5316530443300866, Validation Acc: 0.8205
# Epoch 10, Training Loss: 0.3267725021719933, Train Acc: 0.8900, Validation Loss: 0.5560041591999637, Validation Acc: 0.8187
# Epoch 11, Training Loss: 0.2959017366886139, Train Acc: 0.9012, Validation Loss: 0.505599377356517, Validation Acc: 0.8356
# Epoch 12, Training Loss: 0.274352553319931, Train Acc: 0.9075, Validation Loss: 0.5564427189766221, Validation Acc: 0.8224
# Epoch 13, Training Loss: 0.26098826389312746, Train Acc: 0.9135, Validation Loss: 0.7004768381452864, Validation Acc: 0.7776
# Epoch 14, Training Loss: 0.2542063660383225, Train Acc: 0.9142, Validation Loss: 0.5541782952417993, Validation Acc: 0.8249
# Epoch 15, Training Loss: 0.2436877339720726, Train Acc: 0.9177, Validation Loss: 0.515108748700968, Validation Acc: 0.8308
# Epoch 16, Training Loss: 0.22755928348898888, Train Acc: 0.9247, Validation Loss: 0.6264628995755676, Validation Acc: 0.8032
# Epoch 17, Training Loss: 0.22116713703870775, Train Acc: 0.9259, Validation Loss: 0.6318758126277073, Validation Acc: 0.8098
# Epoch 18, Training Loss: 0.2179251718401909, Train Acc: 0.9276, Validation Loss: 0.537272400062555, Validation Acc: 0.8301
# Epoch 19, Training Loss: 0.2155847411096096, Train Acc: 0.9290, Validation Loss: 0.5241300525369158, Validation Acc: 0.8361
# Epoch 20, Training Loss: 0.21252344798445702, Train Acc: 0.9300, Validation Loss: 0.5585449503105917, Validation Acc: 0.8284
# Epoch 21, Training Loss: 0.21014495221972465, Train Acc: 0.9312, Validation Loss: 0.609206383964818, Validation Acc: 0.8203
# Epoch 22, Training Loss: 0.20579822655320168, Train Acc: 0.9323, Validation Loss: 0.6025287156841558, Validation Acc: 0.8119
# Epoch 23, Training Loss: 0.2100640952527523, Train Acc: 0.9295, Validation Loss: 0.610608941335587, Validation Acc: 0.8082
# Epoch 24, Training Loss: 0.19799703389406204, Train Acc: 0.9345, Validation Loss: 0.5420389152636194, Validation Acc: 0.8298
# Epoch 25, Training Loss: 0.19464989883303643, Train Acc: 0.9355, Validation Loss: 0.607262805578815, Validation Acc: 0.8135
# Epoch 26, Training Loss: 0.1965713785290718, Train Acc: 0.9355, Validation Loss: 0.6451616822534306, Validation Acc: 0.8042
# Epoch 27, Training Loss: 0.18726570572555065, Train Acc: 0.9397, Validation Loss: 0.556309666081219, Validation Acc: 0.8248
# Epoch 28, Training Loss: 0.19073683333694935, Train Acc: 0.9369, Validation Loss: 0.5261612687805656, Validation Acc: 0.8375
# Epoch 29, Training Loss: 0.19589935435056685, Train Acc: 0.9355, Validation Loss: 0.7826415691406104, Validation Acc: 0.7637
# Epoch 30, Training Loss: 0.18231576204001904, Train Acc: 0.9414, Validation Loss: 0.5221589932775801, Validation Acc: 0.8383
# Epoch 31, Training Loss: 0.193387352591753, Train Acc: 0.9360, Validation Loss: 0.5625268719188726, Validation Acc: 0.8213
# Epoch 32, Training Loss: 0.17915070801973343, Train Acc: 0.9415, Validation Loss: 0.6203680363050692, Validation Acc: 0.8128
# Epoch 33, Training Loss: 0.18165407804846764, Train Acc: 0.9398, Validation Loss: 0.6064846826017283, Validation Acc: 0.8155
# Epoch 34, Training Loss: 0.192556837451458, Train Acc: 0.9367, Validation Loss: 0.6336671512123127, Validation Acc: 0.8112
# Epoch 35, Training Loss: 0.18466965815424918, Train Acc: 0.9416, Validation Loss: 0.6620915627023977, Validation Acc: 0.8004
# Epoch 36, Training Loss: 0.17507670657336713, Train Acc: 0.9433, Validation Loss: 0.5335391496966599, Validation Acc: 0.8398
# Epoch 37, Training Loss: 0.17950682255625725, Train Acc: 0.9407, Validation Loss: 0.5833743439548335, Validation Acc: 0.8156
# Epoch 38, Training Loss: 0.18493639415502547, Train Acc: 0.9399, Validation Loss: 0.5117590224287313, Validation Acc: 0.8404
# Epoch 39, Training Loss: 0.1883588494628668, Train Acc: 0.9394, Validation Loss: 0.6347330127172409, Validation Acc: 0.8040
# Epoch 40, Training Loss: 0.17782466141581535, Train Acc: 0.9415, Validation Loss: 0.5948049284660133, Validation Acc: 0.8248
# Epoch 41, Training Loss: 0.1842475476503372, Train Acc: 0.9396, Validation Loss: 0.573005515109202, Validation Acc: 0.8291
# Epoch 42, Training Loss: 0.17555169839859008, Train Acc: 0.9437, Validation Loss: 0.52378701176613, Validation Acc: 0.8400
# Epoch 43, Training Loss: 0.17241178346574307, Train Acc: 0.9447, Validation Loss: 0.48581764633488506, Validation Acc: 0.8533
# Epoch 44, Training Loss: 0.18388754252791406, Train Acc: 0.9397, Validation Loss: 0.6145650068665766, Validation Acc: 0.8146
# Epoch 45, Training Loss: 0.16943290541172026, Train Acc: 0.9445, Validation Loss: 0.5710623909713356, Validation Acc: 0.8305
# Epoch 46, Training Loss: 0.17048806500434877, Train Acc: 0.9454, Validation Loss: 0.5767628475549115, Validation Acc: 0.8202
# Epoch 47, Training Loss: 0.17331657335162162, Train Acc: 0.9437, Validation Loss: 0.5739782239980759, Validation Acc: 0.8308
# Epoch 48, Training Loss: 0.1758955287963152, Train Acc: 0.9427, Validation Loss: 0.5776437202077003, Validation Acc: 0.8221
# Epoch 49, Training Loss: 0.1750753476023674, Train Acc: 0.9427, Validation Loss: 0.5598212957002555, Validation Acc: 0.8296
# Epoch 50, Training Loss: 0.17580161279439926, Train Acc: 0.9425, Validation Loss: 0.6150459757276402, Validation Acc: 0.8078
# Epoch 51, Training Loss: 0.1777702119112015, Train Acc: 0.9412, Validation Loss: 0.488410249447367, Validation Acc: 0.8452
# Epoch 52, Training Loss: 0.17050678454041482, Train Acc: 0.9444, Validation Loss: 0.6175789784189243, Validation Acc: 0.8212
# Epoch 53, Training Loss: 0.17055926884412764, Train Acc: 0.9446, Validation Loss: 0.6426970044708555, Validation Acc: 0.8139
# Epoch 54, Training Loss: 0.17036948722600936, Train Acc: 0.9453, Validation Loss: 0.6117972940396351, Validation Acc: 0.8187
# Epoch 55, Training Loss: 0.16586413281559945, Train Acc: 0.9461, Validation Loss: 0.7390766628798405, Validation Acc: 0.7853
# Epoch 56, Training Loss: 0.17865110477805138, Train Acc: 0.9414, Validation Loss: 0.5394777310122351, Validation Acc: 0.8392
# Epoch 57, Training Loss: 0.1683295940041542, Train Acc: 0.9459, Validation Loss: 0.520097730788076, Validation Acc: 0.8412
# Epoch 58, Training Loss: 0.1673734719634056, Train Acc: 0.9466, Validation Loss: 0.5308927190341767, Validation Acc: 0.8378
# Epoch 59, Training Loss: 0.1742312640309334, Train Acc: 0.9437, Validation Loss: 0.5154169690172383, Validation Acc: 0.8439
# Epoch 60, Training Loss: 0.17563465802073477, Train Acc: 0.9428, Validation Loss: 0.5842237960381113, Validation Acc: 0.8211
# Epoch 61, Training Loss: 0.16833376340270043, Train Acc: 0.9450, Validation Loss: 0.5664634868787353, Validation Acc: 0.8294
# Epoch 62, Training Loss: 0.17217672619223595, Train Acc: 0.9444, Validation Loss: 0.5185349227706338, Validation Acc: 0.8424
# Epoch 63, Training Loss: 0.1676353505283594, Train Acc: 0.9460, Validation Loss: 0.5823995940814353, Validation Acc: 0.8248
# Epoch 64, Training Loss: 0.17272166779339312, Train Acc: 0.9439, Validation Loss: 0.6374885143747755, Validation Acc: 0.8182
# Epoch 65, Training Loss: 0.16752806946933269, Train Acc: 0.9460, Validation Loss: 0.6881207282755785, Validation Acc: 0.7968
# Epoch 66, Training Loss: 0.174906770414114, Train Acc: 0.9433, Validation Loss: 0.5117422180950262, Validation Acc: 0.8446
# Epoch 67, Training Loss: 0.1622424143821001, Train Acc: 0.9477, Validation Loss: 0.5354676578834558, Validation Acc: 0.8336
# Epoch 68, Training Loss: 0.1639507487952709, Train Acc: 0.9481, Validation Loss: 0.5529220525626164, Validation Acc: 0.8287
# Epoch 69, Training Loss: 0.16795985590219498, Train Acc: 0.9468, Validation Loss: 0.561499875821885, Validation Acc: 0.8307
# Epoch 70, Training Loss: 0.1706286841392517, Train Acc: 0.9440, Validation Loss: 0.6024790546696657, Validation Acc: 0.8244
# Epoch 71, Training Loss: 0.1708830202817917, Train Acc: 0.9440, Validation Loss: 0.6011659271398168, Validation Acc: 0.8209
# Epoch 72, Training Loss: 0.16708124614357947, Train Acc: 0.9463, Validation Loss: 0.5956459936632472, Validation Acc: 0.8183
# Epoch 73, Training Loss: 0.16749578688144684, Train Acc: 0.9459, Validation Loss: 0.545276774532476, Validation Acc: 0.8371
# Epoch 74, Training Loss: 0.16786250140368938, Train Acc: 0.9460, Validation Loss: 0.573519277629579, Validation Acc: 0.8260
# Epoch 75, Training Loss: 0.17321855296194552, Train Acc: 0.9448, Validation Loss: 0.5601919650272199, Validation Acc: 0.8283
# Epoch 76, Training Loss: 0.1656024231851101, Train Acc: 0.9464, Validation Loss: 0.5562685526859988, Validation Acc: 0.8298
# Epoch 77, Training Loss: 0.15997824270427227, Train Acc: 0.9494, Validation Loss: 0.6266253008774132, Validation Acc: 0.8201
# Epoch 78, Training Loss: 0.1650943441003561, Train Acc: 0.9467, Validation Loss: 0.6380734557558776, Validation Acc: 0.8142
# Epoch 79, Training Loss: 0.1715489692956209, Train Acc: 0.9439, Validation Loss: 0.5646949806220972, Validation Acc: 0.8260
# Epoch 80, Training Loss: 0.15936566751003264, Train Acc: 0.9486, Validation Loss: 0.579028371745234, Validation Acc: 0.8288
# Epoch 81, Training Loss: 0.16456300434172152, Train Acc: 0.9471, Validation Loss: 0.6541163534115834, Validation Acc: 0.8085
# Epoch 82, Training Loss: 0.1669149891614914, Train Acc: 0.9460, Validation Loss: 0.5812354326058345, Validation Acc: 0.8255
# Epoch 83, Training Loss: 0.1718442404001951, Train Acc: 0.9446, Validation Loss: 0.5318969819386294, Validation Acc: 0.8392
# Epoch 84, Training Loss: 0.16737460080385208, Train Acc: 0.9452, Validation Loss: 0.5448910670390554, Validation Acc: 0.8348
# Epoch 85, Training Loss: 0.16622354872822762, Train Acc: 0.9470, Validation Loss: 0.5591748197604517, Validation Acc: 0.8345
# Epoch 86, Training Loss: 0.1664279383480549, Train Acc: 0.9471, Validation Loss: 0.5296393901489342, Validation Acc: 0.8424
# Epoch 87, Training Loss: 0.16753021379113198, Train Acc: 0.9460, Validation Loss: 0.5438815016465582, Validation Acc: 0.8342
# Epoch 88, Training Loss: 0.17125357215702533, Train Acc: 0.9438, Validation Loss: 0.5439461052987227, Validation Acc: 0.8345
# Epoch 89, Training Loss: 0.1572077605575323, Train Acc: 0.9491, Validation Loss: 0.5931227030647788, Validation Acc: 0.8238
# Epoch 90, Training Loss: 0.16693745223879813, Train Acc: 0.9446, Validation Loss: 0.5472371986337529, Validation Acc: 0.8294
# Epoch 91, Training Loss: 0.1774607043147087, Train Acc: 0.9417, Validation Loss: 0.5199079160477705, Validation Acc: 0.8377
# Epoch 92, Training Loss: 0.15872089017033578, Train Acc: 0.9479, Validation Loss: 0.6428765111668094, Validation Acc: 0.8119
# Epoch 93, Training Loss: 0.17171253317296506, Train Acc: 0.9444, Validation Loss: 0.577819524297289, Validation Acc: 0.8231
# Epoch 94, Training Loss: 0.16181455540657044, Train Acc: 0.9492, Validation Loss: 0.5695522257548039, Validation Acc: 0.8263
# Epoch 95, Training Loss: 0.1624131223797798, Train Acc: 0.9480, Validation Loss: 0.6314696470263658, Validation Acc: 0.8169
# Epoch 96, Training Loss: 0.1654258860439062, Train Acc: 0.9454, Validation Loss: 0.6333738788487805, Validation Acc: 0.8087
# Epoch 97, Training Loss: 0.17220633433461188, Train Acc: 0.9436, Validation Loss: 0.5205928279905562, Validation Acc: 0.8389
# Epoch 98, Training Loss: 0.16080760295689106, Train Acc: 0.9477, Validation Loss: 0.5556847227227156, Validation Acc: 0.8339
# Epoch 99, Training Loss: 0.1625061457067728, Train Acc: 0.9479, Validation Loss: 0.5883084750099546, Validation Acc: 0.8221
# Epoch 100, Training Loss: 0.16294399566948414, Train Acc: 0.9476, Validation Loss: 0.7696657680022488, Validation Acc: 0.7833
# Epoch 101, Training Loss: 0.16219055422246456, Train Acc: 0.9477, Validation Loss: 0.6811269328093074, Validation Acc: 0.7983
# Epoch 102, Training Loss: 0.16894742808938026, Train Acc: 0.9460, Validation Loss: 0.6749845634979806, Validation Acc: 0.7961
# Epoch 103, Training Loss: 0.16570185455679892, Train Acc: 0.9467, Validation Loss: 0.6935431203644746, Validation Acc: 0.7985
# Epoch 104, Training Loss: 0.16040462365448474, Train Acc: 0.9480, Validation Loss: 0.4975228981607279, Validation Acc: 0.8438
# Epoch 105, Training Loss: 0.172474734339118, Train Acc: 0.9450, Validation Loss: 0.5672728651837938, Validation Acc: 0.8291
# Epoch 106, Training Loss: 0.17041436858773232, Train Acc: 0.9452, Validation Loss: 0.5303808154573866, Validation Acc: 0.8409
# Epoch 107, Training Loss: 0.15977608854472636, Train Acc: 0.9491, Validation Loss: 0.5494259528483555, Validation Acc: 0.8351
# Epoch 108, Training Loss: 0.16719848965704442, Train Acc: 0.9466, Validation Loss: 0.4852477673702179, Validation Acc: 0.8520
# Epoch 109, Training Loss: 0.1585338474214077, Train Acc: 0.9488, Validation Loss: 0.6461447921528178, Validation Acc: 0.8108
# Epoch 110, Training Loss: 0.16106909065246583, Train Acc: 0.9482, Validation Loss: 0.5578803523995315, Validation Acc: 0.8317
# Epoch 111, Training Loss: 0.16712952519059182, Train Acc: 0.9470, Validation Loss: 0.675341219848888, Validation Acc: 0.8017
# Epoch 112, Training Loss: 0.16462892461419107, Train Acc: 0.9467, Validation Loss: 0.5737287904236726, Validation Acc: 0.8250
# Epoch 113, Training Loss: 0.16288754999637603, Train Acc: 0.9470, Validation Loss: 0.9389164275044848, Validation Acc: 0.7461
# Epoch 114, Training Loss: 0.16442962102293968, Train Acc: 0.9468, Validation Loss: 0.5833878969880426, Validation Acc: 0.8288
# Epoch 115, Training Loss: 0.16821628403365613, Train Acc: 0.9446, Validation Loss: 0.5483046711250475, Validation Acc: 0.8350
# Epoch 116, Training Loss: 0.16231639521718025, Train Acc: 0.9480, Validation Loss: 0.6263724379478746, Validation Acc: 0.8130
# Epoch 117, Training Loss: 0.16904382219314576, Train Acc: 0.9458, Validation Loss: 0.55359484568523, Validation Acc: 0.8324
# Epoch 118, Training Loss: 0.16393456476330756, Train Acc: 0.9474, Validation Loss: 0.5515181855506198, Validation Acc: 0.8291
# Epoch 119, Training Loss: 0.16205914033949376, Train Acc: 0.9475, Validation Loss: 0.5792930184086417, Validation Acc: 0.8313
# Epoch 120, Training Loss: 0.1612436019986868, Train Acc: 0.9478, Validation Loss: 0.5841142867401148, Validation Acc: 0.8280
# Epoch 121, Training Loss: 0.15827295963168145, Train Acc: 0.9494, Validation Loss: 0.5393568069502047, Validation Acc: 0.8375
# Epoch 122, Training Loss: 0.16196162326335908, Train Acc: 0.9477, Validation Loss: 0.5122307472547908, Validation Acc: 0.8473
# Epoch 123, Training Loss: 0.16886441301703453, Train Acc: 0.9455, Validation Loss: 0.5692049251620177, Validation Acc: 0.8220
# Epoch 124, Training Loss: 0.1582457127213478, Train Acc: 0.9487, Validation Loss: 0.5763162967695552, Validation Acc: 0.8294
# Epoch 125, Training Loss: 0.1623435587912798, Train Acc: 0.9476, Validation Loss: 0.6126705801031392, Validation Acc: 0.8235
# Epoch 126, Training Loss: 0.16729845813214778, Train Acc: 0.9459, Validation Loss: 0.5100866817175203, Validation Acc: 0.8399
# Epoch 127, Training Loss: 0.16547149180173873, Train Acc: 0.9467, Validation Loss: 0.5724495281079772, Validation Acc: 0.8196
# Epoch 128, Training Loss: 0.16308649200201034, Train Acc: 0.9484, Validation Loss: 0.5723523768080268, Validation Acc: 0.8268
# Epoch 129, Training Loss: 0.1569298894047737, Train Acc: 0.9500, Validation Loss: 0.56448558637291, Validation Acc: 0.8335
# Epoch 130, Training Loss: 0.16566248070895673, Train Acc: 0.9478, Validation Loss: 0.6338862219623699, Validation Acc: 0.8182
# Epoch 131, Training Loss: 0.1644582720041275, Train Acc: 0.9477, Validation Loss: 0.6365653228987554, Validation Acc: 0.8176
# Epoch 132, Training Loss: 0.16835831463038922, Train Acc: 0.9459, Validation Loss: 0.6038069083432483, Validation Acc: 0.8193
# Epoch 133, Training Loss: 0.16424686320722104, Train Acc: 0.9469, Validation Loss: 0.5356550374703043, Validation Acc: 0.8374
# Epoch 134, Training Loss: 0.16106500518023967, Train Acc: 0.9486, Validation Loss: 0.6286061134687655, Validation Acc: 0.8096
# Epoch 135, Training Loss: 0.16715341562628747, Train Acc: 0.9464, Validation Loss: 0.5043856436090105, Validation Acc: 0.8475
# Epoch 136, Training Loss: 0.16779923071563244, Train Acc: 0.9443, Validation Loss: 0.5158742983250102, Validation Acc: 0.8389
# Epoch 137, Training Loss: 0.1591651696205139, Train Acc: 0.9492, Validation Loss: 0.6213377038384699, Validation Acc: 0.8128
# Epoch 138, Training Loss: 0.16262414997816085, Train Acc: 0.9471, Validation Loss: 0.4632277291291838, Validation Acc: 0.8599
# Epoch 139, Training Loss: 0.15411392598450183, Train Acc: 0.9514, Validation Loss: 0.5230102992978445, Validation Acc: 0.8422
# Epoch 140, Training Loss: 0.17002688896656037, Train Acc: 0.9445, Validation Loss: 0.49897321033629644, Validation Acc: 0.8444
# Epoch 141, Training Loss: 0.16689899588227272, Train Acc: 0.9466, Validation Loss: 0.6620218358032263, Validation Acc: 0.8045
# Epoch 142, Training Loss: 0.15907751910090445, Train Acc: 0.9495, Validation Loss: 0.5824459007211552, Validation Acc: 0.8310
# Epoch 143, Training Loss: 0.16151746794581412, Train Acc: 0.9479, Validation Loss: 0.6317507324704699, Validation Acc: 0.8154
# Epoch 144, Training Loss: 0.16229296407103538, Train Acc: 0.9486, Validation Loss: 0.4876031467489376, Validation Acc: 0.8512
# Epoch 145, Training Loss: 0.16431702541708945, Train Acc: 0.9472, Validation Loss: 0.6023344446899025, Validation Acc: 0.8190
# Epoch 146, Training Loss: 0.15895040589571, Train Acc: 0.9491, Validation Loss: 0.5935907231015005, Validation Acc: 0.8249
# Epoch 147, Training Loss: 0.1680879157692194, Train Acc: 0.9456, Validation Loss: 0.5907236474334814, Validation Acc: 0.8238
# Epoch 148, Training Loss: 0.1586302920371294, Train Acc: 0.9496, Validation Loss: 0.630015524519477, Validation Acc: 0.8122
# Epoch 149, Training Loss: 0.16547331895828246, Train Acc: 0.9460, Validation Loss: 0.6106938801373646, Validation Acc: 0.8147
# Epoch 150, Training Loss: 0.1650391299903393, Train Acc: 0.9474, Validation Loss: 0.5706502755356443, Validation Acc: 0.8247

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix


# 모델을 평가 모드로 설정
model.eval()

# 테스트 데이터셋에 대한 성능을 평가하기 위한 변수 초기화
test_loss = 0.0
test_corrects = 0

# Confusion matrix를 위한 레이블과 예측값을 저장할 리스트
true_labels = []
pred_labels = []

# GPU 설정 (이미 설정되어 있다면 생략 가능)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

with torch.no_grad():
    for inputs, labels in testloader:
        # 데이터를 GPU로 옮김 (이미 옮겨져 있다면 생략 가능)
        inputs, labels = inputs.to(device), labels.to(device)

        # 모델을 통해 예측 실행
        outputs = model(inputs)

        # 손실 계산
        loss = criterion(outputs, labels)

        # 테스트 손실 업데이트
        test_loss += loss.item() * inputs.size(0)

        # 예측값 계산
        _, preds = torch.max(outputs, 1)

        # 정확도 계산
        test_corrects += torch.sum(preds == labels.data)

        # 레이블과 예측값을 리스트에 추가
        true_labels.extend(labels.cpu().numpy())
        pred_labels.extend(preds.cpu().numpy())

# 평균 테스트 손실과 정확도 계산
test_loss = test_loss / len(testloader.dataset)
test_acc = test_corrects.double() / len(testloader.dataset)

print(f'Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}')

# Confusion matrix 계산
conf_matrix = confusion_matrix(true_labels, pred_labels)

# Confusion matrix를 그림으로 표시
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt="d",xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Test Loss: 0.5877, Test Acc: 0.8185
